# %% [markdown]
# ![images_ahn16_post_ca774083-2384-41d3-8864-142519411a32_Screen Shot 2021-04-20 at 3.17.34 PM.png](data:image/png;base64,...)

# %%
class Solution:
    def fib(self, n: int) -> int:
        if n <= 1:
            return n
        else:
            return self.fib(n-1) + self.fib(n-2)
